# %%
import openai
from pathlib import Path
import requests
import time

OPEN_AI_KEY = "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"
openai.api_key = OPEN_AI_KEY

output = Path("gpt_generated")

output.mkdir(exist_ok=True)


# The language you want to search for
LANGUAGES = [
    # "1C Enterprise",
    # "ABAP",
    # "ActionScript",
    # "Ada",
    # "Groovy",
    # "APEX",
    # "AppleScript",
    # "ASP",
    # "Assembly",
    # "AutoHotKey",
    # "AWK",
    # "Basic",
    # "Batch",
    # "Bison",
    # "C",
    # "Clojure",
    # "CMake",
    # "COBOL",
    # "CoffeeScript",
    # "Lisp",
    # "C++",
    # "Crystal",
    # "C#",
    # "CSS",
    # "CSV",
    # "D",
    # "Dart",
    # "Delphi",
    # "Docker",
    # "Elixir",
    # "Elm",
    # "Erlang",
    # "FIFT",
    # "Forth",
    # "Fortran",
    # "F#",
    # "GAMS",
    # "Go",
    # "Gradle",
    # "GraphQL",
    # "Hack",
    # "Haskell",
    # "HTML",
    # "Icon",
    # "IDL",
    # "INI",
    # "Java",
    # "JavaScript",
    # "JSON",
    # "Julia",
    # "Keyman",
    "Kotlin",
    "LaTeX",
    "Lisp",
    "Logo",
    "Lua",
    "Makefile",
    "Markdown",
    "MATLAB",
    "NGINX",
    "Nim",
    "Objective-C",
    "OCaml",
    "OpenEdgeABL",
    "Pascal",
    "Perl",
    "PHP",
    "SQL",
    "PowerShell",
    "Prolog",
    "Protobuf",
    "Python",
    "QML",
    "R",
    "Raku",
    "Regex",
    "Ruby",
    "Rust",
    "SAS",
    "Scala",
    "Scheme",
    "Shell",
    "Smalltalk",
    "Solidity",
    "SQL",
    "Swift",
    "Tcl",
    "Textile",
    "TL",
    "TypeScript",
    "UnrealScript",
    "Vala",
    "VBScript",
    "Verilog",
    "VisualBasic",
    "Wolfram",
    "XML",
    "YAML",
]

# %%
for lang in LANGUAGES:
    print(f"generating for {lang}")
    # lang = "1C Enterprise"

    # Define the system message
    system_msg = f'You are a helpful {lang} programming assistant who can write any program in {lang}.'

    # Define the user message
    user_msg = f"""
    Create a dataset of 100 code snippets in {lang} language. 
    Each snippet should contain some reasonable code like function or part of code that someone can send to other person to clarify something. 
    Different snippets should be spaced by "=====" line. No comments about what snippet do, no mention of snippets in code. Example for Python:
    =====
    def reverse_string(s):
        return s[::-1]
    =====
    def read_all(filename):
        with open(filename, "r") as file:
            lines = file.readlines()
        return "\n".join(lines)
    =====
    ...
    Remember that snippets should be in the {lang} language (not in Python!!!). Generate in total 100 snippets. 
    Start reply with first snippet code line:
    """.strip()

    # Create a dataset using GPT
    while True:
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[{"role": "system", "content": system_msg},
                        {"role": "user", "content": user_msg}],
                max_tokens=4096 - 250,
            )
            reason = response["choices"][0]["finish_reason"]
            content = response["choices"][0]["message"]["content"]
            break
        except Exception as ex:
            print(f"got exeption {ex} retry")
            time.sleep(5)

    if reason in ["stop", "length"]:
        (output / lang).mkdir(exist_ok=True)

        with open(output / lang / "raw.txt", "a", encoding="utf8") as file:
            file.write("\n=====\n")
            file.write(response["choices"][0]["message"]["content"])
            file.write("\n=====\n")
            
        print(f"{lang} generated, reason {reason}")
    else:
        print(f"{lang} failed, reason {reason}")
# Out:
# Perl generated, reason length
# generating for PHP
# PHP generated, reason length
# generating for SQL
# SQL generated, reason stop
# generating for PowerShell
# PowerShell generated, reason stop
# generating for Prolog
# Prolog generated, reason stop
# generating for Protobuf
# Protobuf generated, reason stop
# generating for Python
# Python generated, reason length
# generating for QML
# QML generated, reason stop
# generating for R
# R generated, reason stop
# generating for Raku
# Raku generated, reason stop
# generating for Regex
# Regex generated, reason stop
# generating for Ruby
# Ruby generated, reason stop
# generating for Rust
# Rust generated, reason length
# generating for SAS
# SAS generated, reason length
# generating for Scala
# Scala generated, reason length
# generating for Scheme
# Scheme generated, reason stop
# generating for Shell
# Shell generated, reason length
# generating for Smalltalk
# Smalltalk generated, reason length
# generating for Solidity
# ...
